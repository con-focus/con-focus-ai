# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) # ->이건 BGR로 나오는것

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))#이건 BGR을 RGB로 바꿔서 더 가독성 높은 사진으로 바꾼것

# %% [markdown]
# ### 감정 분석을 위해 필요한 libray 설치!!

# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.49-py3-none-any.whl (55 kB)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from deepface) (2.3.0)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from deepface) (4.5.1.48)
# Collecting tqdm>=4.30.0
#   Downloading tqdm-4.59.0-py2.py3-none-any.whl (74 kB)
# Collecting keras>=2.2.0
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from deepface) (1.18.5)
# Collecting Flask>=1.1.2
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from deepface) (7.2.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from deepface) (1.1.0)
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-0.1.0-py3-none-any.whl (2.3 MB)
# Collecting gdown>=3.10.1
#   Downloading gdown-3.12.2.tar.gz (8.2 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: scipy==1.4.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.4.1)
# Requirement already satisfied: gast==0.3.3 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.3.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.13.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.31.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.34.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.3.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp37-cp37m-win_amd64.whl (210 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from pandas>=0.23.4->deepface) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: requests[socks] in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from gdown>=3.10.1->deepface) (2.24.0)
# Collecting filelock
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: setuptools in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from protobuf>=3.9.2->tensorflow>=1.9.0->deepface) (49.6.0.post20200814)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.20.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (1.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\ek hong\.conda\envs\tensorflow\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=1.9.0->deepface) (3.1.0)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-3.12.2-py3-none-any.whl size=9681 sha256=7ec731002c01d0287c560b1662ead908ff7e43a66691d945b33e316baca9fccb
#   Stored in directory: c:\users\ek hong\appdata\local\pip\cache\wheels\ba\e0\7e\726e872a53f7358b4b96a9975b04e98113b005cd8609a63abc
# Successfully built gdown
# Installing collected packages: tqdm, pyyaml, keras, itsdangerous, Flask, mtcnn, filelock, gdown, deepface
# Successfully installed Flask-1.1.2 deepface-0.0.49 filelock-3.0.12 gdown-3.12.2 itsdangerous-1.1.0 keras-2.4.3 mtcnn-0.1.0 pyyaml-5.4.1 tqdm-4.59.0

# %% [markdown]
# ### ->현재 detecting에 오류가 생겼음 -> 오류 해결 및 다른 방식을 사용하는 것도 고려 필요
# ### ->이건 1.인자 중 enforce_detection = False 로 두면 해결이 된다!! ,2. action을 emotion만 측정하게 (인종같은 인자 다 버리고)하면 해결 된다!!
# ### ->사진의 비율도 측정하는데 중요한데, 이는 colab으로 짠 코드 참고!!!

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)
#카메라 켜져있는지 확인
#if not cap.isOpened():
#  cap = cv2.VideoCapture(1)
if not cap.isOpened():
  print("Cannot open webcam")

while True:
    ret, frame = cap.read()#비디오에서 image를 읽어오는 것이다
    result = DeepFace.analyze(frame, actions = ['emotion'],enforce_detection = False)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)

    for(x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0 ,255, 0), 2)

    font =  cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, result['dominant_emotion'], (50,50),
            font,3,(0,0,255),
            2,
            cv2.LINE_4)
    cv2.imshow('Demo video', frame)

    key = cv2.waitKey(1) & 0xFF

    if key == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000011BC2EEFCA8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
